# %%
pip install pmdarima
# Out:
# ...
#      |████████████████████████████████| 656 kB 3.3 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, acf
from statsmodels.graphics.tsaplots import plot_pacf, pacf
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from itertools import product
from pmdarima.arima import auto_arima

# %% [markdown]
# # Load Data

# %%
east = pd.read_csv('data/east_daily.csv')
midwest = pd.read_csv('data/midwest_daily.csv') 
south = pd.read_csv('data/south_daily.csv') 
west = pd.read_csv('data/west_daily.csv')

# %% [markdown]
# # Check Stationarity

# %%
X = east.daily_deaths
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -3.842138
# p-value: 0.002504
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %%
X = midwest.daily_deaths
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.473716
# p-value: 0.122001
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %%
X = south.daily_deaths
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -3.104854
# p-value: 0.026196
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %%
X = west.daily_deaths
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.816341
# p-value: 0.055977
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# # Differencing

# %%
plt.figure(figsize=(12, 6))
plt.plot(midwest['daily_deaths'], label='Original Time Series')
plt.title('Original Time Series')
plt.show()

# %%
midwest_stationary = midwest['date'].to_frame().join(midwest['daily_deaths'].diff().fillna(0))

# %%
plt.figure(figsize=(12, 6))
plt.plot(midwest_stationary['daily_deaths'], label='Differenced Time Series')
plt.title('Differenced Time Series')
plt.show()

# %%
south_stationary = south['date'].to_frame().join(south['daily_deaths'].diff().fillna(0))

# %%
west_stationary = west['date'].to_frame().join(west['daily_deaths'].diff().fillna(0))

# %% [markdown]
# # Check Stationarity After Differencing

# %%
X = midwest_stationary.daily_deaths
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -6.612100
# p-value: 0.000000
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %%
X = south_stationary.daily_deaths
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -6.157430
# p-value: 0.000000
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %%
X = west_stationary.daily_deaths
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.691688
# p-value: 0.000001
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# # Create New CSVs

# %%
midwest_stationary.to_csv('midwest_stationary.csv', index = False)

# %%
south_stationary.to_csv('south_stationary.csv', index = False)

# %%
west_stationary.to_csv('west_stationary.csv', index = False)

# %% [markdown]
# # Split Data Into Train and Test

# %%
east_stationary = pd.read_csv('data/east_daily.csv')
midwest_stationary = pd.read_csv('data/midwest_stationary.csv')
south_stationary = pd.read_csv('data/south_stationary.csv')
west_stationary = pd.read_csv('data/west_stationary.csv')

# %%
0.8 * east_stationary.shape[0]
# Out:
# 908.8000000000001

# %%
num_train = 909

east_train = east_stationary.loc[:num_train - 1, :]
east_test = east_stationary.loc[num_train:, :]
east_train = east_train.set_index('date')
east_test = east_test.set_index('date')

midwest_train = midwest_stationary.loc[:num_train - 1, :]
midwest_test = midwest_stationary.loc[num_train:, :]
midwest_train = midwest_train.set_index('date')
midwest_test = midwest_test.set_index('date')

south_train = south_stationary.loc[:num_train - 1, :]
south_test = south_stationary.loc[num_train:, :]
south_train = south_train.set_index('date')
south_test = south_test.set_index('date')

west_train = west_stationary.loc[:num_train - 1, :]
west_test = west_stationary.loc[num_train:, :]
west_train = west_train.set_index('date')
west_test = west_test.set_index('date')

# %% [markdown]
# # East

# %% [markdown]
# ### ACF and PACF

# %%
acf_values, confint = acf(east_stationary['daily_deaths'], alpha=0.05,nlags=110)
lags = np.arange(0, len(acf_values))

lower_bound = confint[1:, 0] - acf_values[1:]
upper_bound = confint[1:, 1] - acf_values[1:]

plt.bar(lags, acf_values, width=0.5, align='center', label='ACF')
plt.fill_between(lags[1:], lower_bound, upper_bound, color='grey', alpha=0.2, label='95% Confidence Interval')
plt.plot(lags[1:], upper_bound, color='grey', lw=0.3)
plt.plot(lags[1:], lower_bound, color='grey', lw=0.3)
plt.xlabel('Lags')
plt.tight_layout()

# %%
acf_values, confint = pacf(east_stationary['daily_deaths'], alpha=0.05,nlags=10)
lags = np.arange(0, len(acf_values))

lower_bound = confint[1:, 0] - acf_values[1:]
upper_bound = confint[1:, 1] - acf_values[1:]

plt.bar(lags, acf_values, width=0.5, align='center', label='ACF')
plt.fill_between(lags[1:], lower_bound, upper_bound, color='red', alpha=0.2, label='95% Confidence Interval')
plt.plot(lags[1:], upper_bound, color='grey', lw=0.3)
plt.plot(lags[1:], lower_bound, color='grey', lw=0.3)
plt.xlabel('Lags')
plt.tight_layout()

# %% [markdown]
# ACF tails off and PACF cutoff at lag 2 -> AR(2) model

# %% [markdown]
# ### AR(2) Model

# %%
model = ARIMA(east_train, order=(2, 0, 0))
model = model.fit()

train_pred=model.fittedvalues
pd.concat([east_train, train_pred], axis=1).plot(figsize=(20, 8))
plt.legend(['train_gt', 'train_pred'])
plt.show()

east_test.index = pd.to_datetime(east_test.index)

test_pred=model.predict(start=len(east_train), end=len(east_train)+len(east_test)-1, dynamic=True)
pd.concat([east_test, test_pred], axis=1).plot()
plt.legend(['test_gt', 'test_pred'])
plt.show()

# Calculate RMSE, R-squared, and MAE for the training set
rmse_train = np.sqrt(mean_squared_error(east_train, train_pred))
r2_train = r2_score(east_train, train_pred)
mae_train = mean_absolute_error(east_train, train_pred)

print("Training Set Metrics:")
print("RMSE:", rmse_train)
print("R-squared:", r2_train)

# Calculate RMSE, R-squared, and MAE for the testing set
rmse_test = np.sqrt(mean_squared_error(east_test, test_pred))
r2_test = r2_score(east_test, test_pred)
mae_test = mean_absolute_error(east_test, test_pred)

print("\nTesting Set Metrics:")
print("RMSE:", rmse_test)
print("R-squared:", r2_test)
# Out:
# /Users/alissachu/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/alissachu/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/alissachu/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# Training Set Metrics:
# RMSE: 111.8150611123132
# R-squared: 0.8395606848514352
#
# Testing Set Metrics:
# RMSE: 161.53370255049225
# R-squared: -1.5075118677127683

# %% [markdown]
# ### auto ARIMA

# %%
model = auto_arima(east_train, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(model.aic())
# Out:
# Performing stepwise search to minimize aic
# /Users/alissachu/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=inf, Time=1.18 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=11814.489, Time=0.08 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=11560.985, Time=0.53 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.93 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=11815.725, Time=0.16 sec
# /Users/alissachu/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=11332.210, Time=1.10 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=3.66 sec
# ...

# %%
train_pred=model.fittedvalues()
pd.concat([east_train, train_pred], axis=1).plot(figsize=(20,8))
plt.legend(['train', 'train_pred'])
plt.show()

test_pred=model.predict(n_periods=len(east_test))
pd.concat([east_test, test_pred], axis=1).plot()

plt.legend(['test', 'test_pred'])

# Calculate RMSE, R-squared, and MAE for the training set
rmse_train = np.sqrt(mean_squared_error(east_train, train_pred))
r2_train = r2_score(east_train, train_pred)
mae_train = mean_absolute_error(east_train, train_pred)

print("Training Set Metrics:")
print("RMSE:", rmse_train)
print("R-squared:", r2_train)

# Calculate RMSE, R-squared, and MAE for the testing set
rmse_test = np.sqrt(mean_squared_error(east_test, test_pred))
r2_test = r2_score(east_test, test_pred)
mae_test = mean_absolute_error(east_test, test_pred)

print("\nTesting Set Metrics:")
print("RMSE:", rmse_test)
print("R-squared:", r2_test)
# Out:
# Training Set Metrics:
# RMSE: 104.23076298973272
# R-squared: 0.8605874014233929
#
# Testing Set Metrics:
# RMSE: 96.70254424807978
# R-squared: 0.10134601862923676
